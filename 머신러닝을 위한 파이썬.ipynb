# %% [markdown]
# ### 1. import

# %%
# 판다스, 넘파이, 맷플롭립 라이브러리 import

# %% [markdown]
# ### 2. 문자

# %%
word1 = "hello"
word2 = 'hello'

# %% [markdown]
# ### 3. type

# %%
#문자(str), 숫자문자

# %%
#정수(int)

# %%
#실수(float)

# %%
#데이터 타입 변환

# %% [markdown]
# ### 4. list & slicing
# 대괄호([]) 안에 복수개의 데이터를 넣어준 집합

# %%
#1차원 리스트

# %%
#2차원 리스트

# %% [markdown]
# ##### 4-1. 색인(index)
# 색인은 0번부터 시작

# %%
#x[0]

# %%
#-1은 거꾸로 색인

# %% [markdown]
# ##### 4-2. 슬라이싱

# %%
#콜론(:)을 기준으로 왼쪽은 포함, 오른쪽은 미만

# %% [markdown]
# ### 5. 함수

# %%
#함수정의, 활용방법
#들여쓰기 주의
# def 함수명(파라미터1, 파라미터2):
#     들여쓰기

# %% [markdown]
# ### 6. 조건문

# %% [markdown]
# ### 7. for in 구문(반복문)

# %%
# for 변수명 in range, 리스트
